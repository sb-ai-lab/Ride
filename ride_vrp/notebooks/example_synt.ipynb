# %% [markdown]
# # Ноутбук с примером работы для грузов с синтетическими позициями (из графа OSM)
# Чтобы не спамить гис, в качестве сервиса поиска расстояний используется граф OSM

# %%
import sys
sys.path.append('../')

# %%
import datetime
import random

import folium
import pandas as pd
from itertools import groupby
import pickle
import networkx as nx
import osmnx as ox
import os
from scripts.cargo_delivery import delivery, PathBuildingResult
from scripts.data_model import Cargo, Tariff, TariffCost
from itertools import count

from heapq import heappush, heappop

# %% [markdown]
# Загрузка и валидация данных (грузы только между двумя точками)

# %%
df_mos = pd.read_excel('../data/05_Грузы (только 2 точки) 2025-04-07.xlsx')
df_cpy = df_mos

# %%
df_cpy['Кол-во заявок по ручному ID (со схожей датой сбора и городами доставки и отправления)'].unique()
# Out:
# array([969, 394,  41,  13,   7,  35,  17, 282, 129,   1, 416, 264, 656,
#        191, 165, 121,  84, 138,  26, 108,  66, 139,  24, 104, 128,  94,
#         83,   6, 115,  76, 106,  79,   2,  11,   4, 181,  10, 120,  87,
#        117,  52,  30, 136,  50,  48,  90,  44,   3,  42,  43, 589, 177,
#         45,   8,  14,   5,  12,  37,  15,   9,  54, 118,  67,  39,  23,
#         89,  36,  29,  81,  18,  25, 176, 111,  20,  22,  33,  19,  21,
#         16,  61,  74,  28,  32, 273,  47,  34, 281, 285, 233,  27,  92,
#         56, 182, 100,  57,  40,  31,  49,  60])

# %%
df_mos = df_cpy[df_cpy['Кол-во заявок по ручному ID (со схожей датой сбора и городами доставки и отправления)'] == 108]
df_mos = df_mos[df_mos['Количество точек'] == 2]

# %% [markdown]
# Вытаскиваем характеристики по массе объему по разным машинам

# %%
cars_df = pd.read_excel('../data/Автомобили Логистика.xlsx', sheet_name='Лист2')
cars_df = cars_df[cars_df['Категория груза'] == 'Обычные']
car_name_to_mass_volume = {r['Наименование автомобиля']: (r['Грузоподъемность, (кг)'], r['Объем, (м³)']) for _, r in
                           cars_df.iterrows() if
                           'миксер' not in r['Наименование автомобиля'] and r['Грузоподъемность, (кг)'] <= 10000}
del cars_df

# %%
car_name_to_mass_volume
# Out:
# {'ТС 7,0 тонн с гидролифтом': (7000, 33.0),
#  'ТС 0,75 тонн': (750, 1.713408),
#  'Средний грузовик': (3000, 23.0),
#  'Большой грузовик': (5000, 36.0),
#  'ТС 7.0 тонн': (7000, 44.0),
#  'Мерседес Крытый 7 тонн': (7000, 44.0),
#  'Фургон': (1500, 12.0),
#  'Малый грузовик': (1500, 16.0),
#  'Газель 1.5т': (1500, 12.0),
#  'ТС 1,5 тонн': (1500, 8.0),
#  'ТС 3,0 тонн': (3000, 18.5),
#  'ТС 5,0 тонн': (5000, 35.0),
#  'ТС 5,0 тонн с гидролифтом': (5000, 35.0),
#  'ТС 3,0 тонн с гидролифтом': (3000, 18.5),
#  'ТС 0,9 тонн': (800, 2.0),
#  'ТС 0,05': (50, 0.5),
#  'ТС 0,45 тонн': (450, 1.0),
#  'ТС 10,0 тонн с гидролифтом': (10000, 50.0)}

# %% [markdown]
# Вытасуиваем тарифы

# %%
cost_df = pd.read_excel('../data/Тарифы Логистика.xlsx')
cost_df = cost_df[cost_df.apply(lambda r: 'Москва' in r['Регион'] and 'и' not in r['Регион'], axis=1)]

# %%
tariffs: list[Tariff] = []

for _, r in cost_df.iterrows():
    if r['Автомобиль'] not in car_name_to_mass_volume:
        continue
    tariffs.append(
        Tariff(
            id=r['Автомобиль'],
            mass=car_name_to_mass_volume[r['Автомобиль']][0],
            volume=car_name_to_mass_volume[r['Автомобиль']][1],
            cost_per_distance=[
                TariffCost(
                    min_dst_km=0,
                    max_dst_km=r['Минимальная поездка, км'],
                    cost_per_km=0,
                    fixed_cost=int(r['Стоимость мин. поездки, коп'] / 100)
                ),
                TariffCost(
                    min_dst_km=r['Минимальная поездка, км'],
                    max_dst_km=r['Максимальная протяженность маршрута, км'],
                    cost_per_km=int(r['Стоимость за км'] / 100),
                    fixed_cost=0
                )
            ])
    )

# %%
del cost_df

# %%
tariffs
# Out:
# [Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=990), TariffCost(min_dst_km=30.0, max_dst_km=2000.0, cost_per_km=33, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1171), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=39, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1171), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=39, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн с гидролифтом', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн с гидролифтом', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн с гидролифтом', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1037), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=34, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн с гидролифтом', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн с гидролифтом', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1484), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=49, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1350), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=45, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1171), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=39, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1500), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=50, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн с гидролифтом', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=20.0, cost_per_km=0, fixed_cost=1800), TariffCost(min_dst_km=20.0, max_dst_km=800.0, cost_per_km=90, fixed_cost=0)]),
#  Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=20.0, cost_per_km=0, fixed_cost=1800), TariffCost(min_dst_km=20.0, max_dst_km=1100.0, cost_per_km=90, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=60.0, cost_per_km=0, fixed_cost=1716), TariffCost(min_dst_km=60.0, max_dst_km=500.0, cost_per_km=28, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=60.0, cost_per_km=0, fixed_cost=1716), TariffCost(min_dst_km=60.0, max_dst_km=500.0, cost_per_km=28, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=60.0, cost_per_km=0, fixed_cost=1716), TariffCost(min_dst_km=60.0, max_dst_km=500.0, cost_per_km=28, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=60.0, cost_per_km=0, fixed_cost=1716), TariffCost(min_dst_km=60.0, max_dst_km=500.0, cost_per_km=28, fixed_cost=0)]),
#  Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=600.0, cost_per_km=0, fixed_cost=16082), TariffCost(min_dst_km=600.0, max_dst_km=800.0, cost_per_km=100, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1037), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=34, fixed_cost=0)]),
#  Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=883), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=29, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1200), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=40, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн с гидролифтом', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1650), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=55, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1200), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=40, fixed_cost=0)]),
#  Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=883), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=29, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1037), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=34, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1350), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=45, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн с гидролифтом', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1650), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=55, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1500), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=50, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн с гидролифтом', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1650), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=55, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн с гидролифтом', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1650), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=55, fixed_cost=0)]),
#  Tariff(id='ТС 7,0 тонн с гидролифтом', mass=7000, volume=33.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1800), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=60, fixed_cost=0)]),
#  Tariff(id='ТС 7,0 тонн с гидролифтом', mass=7000, volume=33.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1800), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=60, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн с гидролифтом', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1484), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=49, fixed_cost=0)]),
#  Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=883), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=29, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1484), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=49, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1171), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=39, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1484), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=49, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн с гидролифтом', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн с гидролифтом', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн с гидролифтом', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1037), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=34, fixed_cost=0)]),
#  Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=883), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=29, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1171), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=39, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1037), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=34, fixed_cost=0)]),
#  Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=883), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=29, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1484), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=49, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн с гидролифтом', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=883), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=29, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн с гидролифтом', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1574), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=52, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1484), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=49, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1171), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=39, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=800), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=100, fixed_cost=0)]),
#  Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1320), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=44, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1485), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=49, fixed_cost=0)]),
#  Tariff(id='ТС 3,0 тонн с гидролифтом', mass=3000, volume=18.5, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1815), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=60, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1650), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=55, fixed_cost=0)]),
#  Tariff(id='ТС 5,0 тонн с гидролифтом', mass=5000, volume=35.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1815), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=60, fixed_cost=0)]),
#  Tariff(id='ТС 7,0 тонн с гидролифтом', mass=7000, volume=33.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1980), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=66, fixed_cost=0)])]

# %% [markdown]
# Удаление дублей тарифов (опционально, просто в таблице много лишних дублей)

# %%
def key(t: Tariff):
    return t.mass, t.volume


new_tariffs = []
for k, v in groupby(sorted(tariffs, key=key), key=key):
    v = list(v)[0]
    new_tariffs.append(v)
tariffs = new_tariffs

# %%
len(tariffs)
# Out:
# 5

# %% [markdown]
# # Загрузка графа OSM

# %%
def get_path(folder: str, name: str):
    if not os.path.exists('../data'):
        os.mkdir('../data')
    path = os.path.join('../data', folder)
    if not os.path.exists(path):
        os.mkdir(path)
    return os.path.join(path, name)


# load graph
def get_graph(city_id: str = 'R2555133', dir=False) -> nx.Graph | nx.DiGraph:
    id_graph = city_id
    name = f'{id_graph}.pickle' if not dir else f'{id_graph}_dit.pickle'
    path = get_path('graphs', name)
    if os.path.exists(path):
        if dir:
            with open(path, 'rb') as fp:
                g: nx.DiGraph = pickle.load(fp)
                fp.close()
        else:
            with open(path, 'rb') as fp:
                g: nx.Graph = pickle.load(fp)
                fp.close()
    else:
        g = _get_gr(id_graph, dir)
        with open(path, 'wb') as fp:
            pickle.dump(g, fp)
            fp.close()
    assert g is not None
    g.remove_edges_from(nx.selfloop_edges(g))
    return g


def _get_gr(city_id, dir):
    gdf = ox.geocode_to_gdf(city_id, by_osmid=True)
    polygon_boundary = gdf.unary_union
    graph = ox.graph_from_polygon(polygon_boundary,
                                  network_type='drive',
                                  simplify=True)
    if dir:
        H = nx.DiGraph()
    else:
        H = nx.Graph()
    # Добавляем рёбра в новый граф, копируя только веса
    for u, d in graph.nodes(data=True):
        H.add_node(u, x=d['y'], y=d['x'])
    for u, v, d in graph.edges(data=True):
        if u == v:
            continue
        H.add_edge(u, v, length=d['length'])
    del city_id, gdf, polygon_boundary, graph
    return H

# %% [markdown]
# Это граф, на котором будут считаться расстояния, чтобы не спамить лищний раз гис

# %%
GRAPH_ID = 'R2555133'  # R13470549 R2555133 R3766483
# примеры id есть в graph_osm_loader.py
g = get_graph(GRAPH_ID)
print(len(g.nodes), len(g.edges))
# Out:
# 18071 27261

# %% [markdown]
# семл рандомных "адресов"

# %%
addresses = random.sample(list(g.nodes), 100)

# %%
cargos: list[Cargo] = []


def get_time(param):
    param = str(param)
    if len(param) > 10:
        if '.' in param:
            return datetime.datetime.strptime(param, '%d.%m.%Y %H:%M:%S')
        else:
            return datetime.datetime.strptime(param, '%Y-%m-%d %H:%M:%S')
    else:
        return datetime.datetime.strptime(param, '%Y-%m-%d')

# парсим грузы из датафрейма
for i, r in df_mos.iterrows():
    start_node = random.choice(addresses)  # берем рандомные адреса из списка
    end_node = random.choice(addresses)
    while start_node == end_node:
        end_node = random.choice(addresses)
    l = nx.dijkstra_path_length(g, start_node, end_node, weight='length')

    mass = min(r['Вес, кг'], 100000)
    volume = min(r['Объем, м3'], 10)
    cm = r['ТРАНСПОРТ Грузоподъемность, (кг)']
    cv = r['ТРАНСПОРТ Объем, (м³)']
    d = Cargo(
        id=r['Номер заявки'],
        nodes=[start_node, end_node],
        mass=[mass, -mass],
        volume=[volume, -volume],
        service_time_minutes=[15, 15]
    )
    cargos.append(d)

# %%
# метод поиска пути для osm нужем только для работы ноутбука
def find_path_to_set(
        graph: nx.Graph,
        start: int,
        ends: set[int],
        left_cost: float = 5000) -> dict[object, float]:
    """
        Поиск пути от точки до множества точек
    :param graph: 
    :param start: 
    :param ends: 
    :param left_cost: 
    :return: 
    """
    adjacency = graph._adj
    c = count()
    push = heappush
    pop = heappop
    dist = {start: (0.0, 0.0, None)}
    fringe = []
    push(fringe, (0.0, 0.0, next(c), start))
    visited = set()
    nodes = graph.nodes()

    while fringe:
        (d, d0, _, v) = pop(fringe)
        if v in ends:
            visited.add(v)
        if len(visited) == len(ends):
            break
        for u, e in adjacency[v].items():
            vu_dist = d0 + e['length']
            vu_dist_n = d + e['length']
            if u not in dist or dist[u][0] > vu_dist_n:
                dist[u] = (vu_dist_n, vu_dist, v)
                push(fringe, (vu_dist_n, vu_dist, next(c), u))

    return {u: d[1] for u, d in dist.items()}

# %%
from sklearn.neighbors import KDTree

node2number = {u: i for i, u in enumerate(g.nodes())}
number2node = {i: u for i, u in enumerate(g.nodes())}
tree = KDTree([[d['x'], d['y']] for u, d in g.nodes(data=True)], leaf_size=10)


# получение ближайшей ноды графа по координатам
def get_near_nodes(coords, k=1) -> list[int]:
    x, y = coords
    dst, res = tree.query([[x, y]], k=k)
    # tree.query_radius()
    return [number2node[u] for u in res[0]]

# %%
def get_distance_matrix(points, start2end, k_near=-1):
    """
        Построение матрицы смежности по графу из OSM
    """
    dsts = {}
    for p in points:
        if k_near <= 0:
            others = {p2 for p2 in points if p2 != p and (p2, p) not in dsts}
        elif k_near >= 1:
            others = {p2 for p2 in get_near_nodes((g.nodes()[p]['x'], g.nodes()[p]['y']), k=k_near) if
                      p2 != p and (p2, p) not in dsts}
        else:
            raise Exception
        if p in start2end:
            others.update(start2end[p])
        paths = find_path_to_set(g, p, others)
        for p2 in others:
            dsts[p, p2] = paths[p2]
            dsts[p2, p] = paths[p2]
    return dsts

# %%
coords = {u: [d['x'], d['y']] for u, d in g.nodes(data=True)}
start2end = {}
for crg in cargos:
    u, v = crg.nodes
    if u not in start2end:
        start2end[u] = set()
    if v not in start2end:
        start2end[v] = set()
    start2end[u].add(v)
    start2end[v].add(u)

dsts = get_distance_matrix(addresses, start2end, k_near=-1)
time_mat = {k:v/1000 for k,v in dsts.items()}

# %%
cargos = cargos[:10]

# %%
tariffs[0]
# Out:
# Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=990), TariffCost(min_dst_km=30.0, max_dst_km=2000.0, cost_per_km=33, fixed_cost=0)])

# %% [markdown]
# # Основной запуск модели

# %%
result = delivery(
    cargos,
    tariffs,
    points_to_coordinate=coords,
    distance_matrix=dsts,
    time_matrix=time_mat
)
# Out:
# 2025-05-15 11:17:25,855 - cargo_delivery [INFO] - начало мержа грузов
# 2025-05-15 11:17:25,856 - cargo_delivery [INFO] - грузы объединены: было 10 стало 10
# 2025-05-15 11:17:25,856 - cargo_delivery [INFO] - количество точек: 18
# 2025-05-15 11:17:25,856 - cargo_delivery [INFO] - Начало создания графа грузов
# 2025-05-15 11:17:25,857 - cargo_delivery [INFO] - Граф грузов создан: 20 нод и 380 ребер
# 2025-05-15 11:17:25,858 - routing_model [INFO] - problem size: 20
# 2025-05-15 11:17:25,858 - routing_model [INFO] - prepare data for model
# 2025-05-15 11:17:25,859 - routing_model [INFO] - Начало создания модели
# 2025-05-15 11:17:25,860 - routing_model [INFO] - Добавление размерности для расстояния
# 2025-05-15 11:17:25,861 - routing_model [INFO] - Добавление размерности для расстояния
# 2025-05-15 11:17:25,861 - routing_model [INFO] - Добавление стоимостей машин
# 2025-05-15 11:17:25,861 - routing_model [INFO] - Добавление ограничений для пройденного расстояния
# 2025-05-15 11:17:25,862 - routing_model [INFO] - Добавление ограничения для порядка доставки
# 2025-05-15 11:17:25,863 - routing_model [INFO] - Добавление ограничений для массы
# 2025-05-15 11:17:25,863 - routing_model [INFO] - Добавление ограничений для объема
# 2025-05-15 11:17:25,866 - routing_model [INFO] - Начало решения
# 2025-05-15 11:17:25,914 - routing_model [INFO] - find new solution: 6977000, best solution: 6977000
# 2025-05-15 11:17:26,304 - routing_model [INFO] - find new solution: 6977000, best solution: 6977000
# 2025-05-15 11:17:26,511 - routing_model [INFO] - find new solution: 6977000, best solution: 6977000
# 2025-05-15 11:17:26,775 - routing_model [INFO] - find new solution: 8014000, best solution: 6977000
# 2025-05-15 11:17:26,816 - routing_model [INFO] - find new solution: 8014000, best solution: 6977000
# 2025-05-15 11:17:26,823 - routing_model [INFO] - find new solution: 6977000, best solution: 6977000
# 2025-05-15 11:17:27,289 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:27,428 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:27,559 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:27,657 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:27,820 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:17:27,887 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:27,894 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:28,039 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:28,269 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:28,624 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:28,627 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:28,628 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:28,644 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:28,676 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:29,014 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:29,029 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:29,032 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:29,061 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:29,085 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:29,115 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:29,140 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:29,315 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:29,568 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:29,576 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:29,598 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:29,636 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:29,674 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:29,732 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:29,746 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:29,756 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:29,765 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:29,944 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:30,051 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:30,199 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:17:30,200 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:30,452 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:30,453 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:30,463 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:30,471 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:30,481 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:30,483 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:30,499 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:30,733 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:30,736 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:30,741 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:30,742 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:30,776 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:30,784 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:30,792 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:31,017 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:31,018 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:31,033 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:31,038 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:31,072 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:31,083 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:31,297 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:31,313 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:31,317 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:31,564 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:31,583 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:31,590 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:17:31,591 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:17:31,624 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:31,634 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:31,635 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:31,724 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:31,950 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:31,955 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:31,963 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:32,031 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:32,042 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:32,118 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:32,248 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:17:32,249 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:17:32,273 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:17:32,279 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:17:32,292 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:17:32,303 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:32,314 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:32,364 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:32,559 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:17:32,563 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:32,566 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:17:32,567 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:32,609 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:32,638 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:32,848 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:32,879 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:32,904 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:33,071 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:33,253 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:33,267 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:33,279 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:33,290 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:33,303 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:33,313 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:33,337 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:33,552 - routing_model [INFO] - find new solution: 7393000, best solution: 5987000
# 2025-05-15 11:17:33,564 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:17:33,568 - routing_model [INFO] - find new solution: 7393000, best solution: 5987000
# 2025-05-15 11:17:33,576 - routing_model [INFO] - find new solution: 7259000, best solution: 5987000
# 2025-05-15 11:17:33,580 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:33,584 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:33,590 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:33,615 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:33,621 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:33,727 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:33,914 - routing_model [INFO] - find new solution: 6262000, best solution: 5987000
# 2025-05-15 11:17:33,921 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:33,954 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:33,967 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:33,972 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:33,984 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:34,248 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:34,356 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:34,676 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:34,806 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:35,078 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:35,178 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:35,224 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:35,275 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:35,555 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:35,557 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:35,921 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:35,923 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:36,276 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:36,640 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:36,645 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:36,651 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:37,012 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:37,382 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:37,389 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:17:37,454 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:37,465 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:37,493 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:37,806 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:17:37,829 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:17:37,842 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:17:37,856 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:37,889 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:38,255 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:38,268 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:38,693 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:17:38,703 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:17:38,736 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:17:38,768 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:38,778 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:38,785 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:17:39,150 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:17:39,201 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:39,319 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:39,578 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:39,971 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:39,976 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:39,980 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:39,983 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:39,992 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:40,040 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:40,056 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:40,144 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:40,177 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:40,213 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:40,259 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:40,496 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:40,503 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:40,508 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:40,596 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:40,704 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:40,836 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:40,864 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:40,872 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:40,903 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:41,140 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:17:41,175 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:41,177 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:41,318 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:41,449 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:41,647 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:41,649 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:41,944 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:41,946 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:42,230 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:42,535 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:42,543 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:42,567 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:17:42,849 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:17:43,154 - routing_model [INFO] - find new solution: 6524000, best solution: 5987000
# 2025-05-15 11:17:43,209 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:43,210 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:43,464 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:17:43,518 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:43,519 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:43,777 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:17:43,832 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:44,088 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:44,096 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:44,115 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:44,122 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:44,136 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:44,143 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:44,149 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:44,162 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:44,436 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:44,500 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:44,770 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:44,799 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:44,810 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:44,824 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:44,838 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:44,844 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:44,852 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:44,862 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:45,132 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:45,136 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:45,156 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:45,182 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:45,203 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:45,218 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:45,231 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:45,356 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:45,667 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:46,041 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:46,060 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:46,062 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:46,064 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:46,080 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:46,103 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:46,196 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:46,258 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:46,344 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:46,360 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:46,632 - routing_model [INFO] - find new solution: 6356000, best solution: 5987000
# 2025-05-15 11:17:46,672 - routing_model [INFO] - find new solution: 6309000, best solution: 5987000
# 2025-05-15 11:17:46,804 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:46,840 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:46,844 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:46,854 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:47,222 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:47,262 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:47,270 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:47,291 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:47,312 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:47,682 - routing_model [INFO] - find new solution: 6309000, best solution: 5987000
# 2025-05-15 11:17:47,683 - routing_model [INFO] - find new solution: 6309000, best solution: 5987000
# 2025-05-15 11:17:47,691 - routing_model [INFO] - find new solution: 6262000, best solution: 5987000
# 2025-05-15 11:17:47,751 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:48,120 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:48,137 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:48,156 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:48,171 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:48,182 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:48,188 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:48,568 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:48,573 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:48,589 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:48,600 - routing_model [INFO] - find new solution: 6309000, best solution: 5987000
# 2025-05-15 11:17:48,609 - routing_model [INFO] - find new solution: 6262000, best solution: 5987000
# 2025-05-15 11:17:48,615 - routing_model [INFO] - find new solution: 6262000, best solution: 5987000
# 2025-05-15 11:17:48,639 - routing_model [INFO] - find new solution: 6309000, best solution: 5987000
# 2025-05-15 11:17:48,653 - routing_model [INFO] - find new solution: 6443000, best solution: 5987000
# 2025-05-15 11:17:48,661 - routing_model [INFO] - find new solution: 6396000, best solution: 5987000
# 2025-05-15 11:17:48,692 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:17:49,056 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:17:49,082 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:17:49,119 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:49,121 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:49,484 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:49,491 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:49,540 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:49,903 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:49,915 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:49,935 - routing_model [INFO] - find new solution: 6262000, best solution: 5987000
# 2025-05-15 11:17:49,964 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:49,976 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:50,013 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:50,365 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:50,370 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:17:50,375 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:50,430 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:50,450 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:50,800 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:50,805 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:50,814 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:50,838 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:17:50,853 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:51,261 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:51,279 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:51,284 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:51,308 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:51,311 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:51,698 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:51,704 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:51,710 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:51,785 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:51,799 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:52,162 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:52,167 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:52,190 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:17:52,212 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:52,242 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:52,251 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:52,257 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:52,263 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:52,264 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:52,290 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:52,397 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:52,647 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:52,889 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:53,163 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:53,564 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:53,566 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:53,566 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:53,568 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:53,571 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:53,963 - routing_model [INFO] - find new solution: 6222000, best solution: 5987000
# 2025-05-15 11:17:53,980 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:54,378 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:54,384 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:54,400 - routing_model [INFO] - find new solution: 6128000, best solution: 5987000
# 2025-05-15 11:17:54,404 - routing_model [INFO] - find new solution: 6175000, best solution: 5987000
# 2025-05-15 11:17:54,425 - routing_model [INFO] - find new solution: 6309000, best solution: 5987000
# 2025-05-15 11:17:54,430 - routing_model [INFO] - find new solution: 6262000, best solution: 5987000
# 2025-05-15 11:17:54,458 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:54,571 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:54,850 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:54,892 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:17:54,907 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:54,915 - routing_model [INFO] - find new solution: 6081000, best solution: 5987000
# 2025-05-15 11:17:55,113 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:55,414 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:55,443 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:55,489 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:55,868 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:55,877 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:17:55,899 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:17:55,938 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:56,089 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:56,398 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:56,815 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:56,820 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:57,248 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:57,668 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:57,981 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:58,082 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:58,219 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:58,387 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:58,388 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:58,391 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:58,720 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:58,762 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:17:58,775 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:59,080 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:17:59,106 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:17:59,125 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:17:59,132 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:59,447 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:59,621 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:59,623 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:59,627 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:17:59,966 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:17:59,985 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:17:59,997 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:18:00,002 - routing_model [INFO] - find new solution: 6349000, best solution: 5987000
# 2025-05-15 11:18:00,007 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:00,016 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:00,045 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:00,356 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:00,403 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:00,719 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:18:00,721 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:18:01,085 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:01,100 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:01,121 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:01,467 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:18:01,468 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:18:01,524 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:01,836 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:02,022 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:02,023 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:02,375 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:02,730 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:02,737 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:03,076 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:03,127 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:03,151 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:18:03,160 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:18:03,467 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:18:03,471 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:03,490 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:03,825 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:03,868 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:18:04,188 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:18:04,189 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:18:04,218 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:18:04,221 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:18:04,226 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:04,570 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:18:04,575 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:18:04,599 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:18:04,602 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:04,776 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:05,022 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:05,249 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:05,658 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:06,066 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:06,471 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:06,481 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:18:06,890 - routing_model [INFO] - find new solution: 6121000, best solution: 5987000
# 2025-05-15 11:18:07,305 - routing_model [INFO] - find new solution: 6524000, best solution: 5987000
# 2025-05-15 11:18:07,377 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:07,729 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:07,738 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:07,755 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:18:07,760 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:07,772 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:07,789 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:07,801 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:07,814 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:08,183 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:08,212 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:08,227 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:08,240 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:08,258 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:18:08,263 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:08,270 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:08,629 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:08,635 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:18:08,640 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:08,647 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:08,664 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:18:08,670 - routing_model [INFO] - find new solution: 6349000, best solution: 5987000
# 2025-05-15 11:18:08,675 - routing_model [INFO] - find new solution: 6349000, best solution: 5987000
# 2025-05-15 11:18:08,696 - routing_model [INFO] - find new solution: 6349000, best solution: 5987000
# 2025-05-15 11:18:08,712 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:08,724 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:09,091 - routing_model [INFO] - find new solution: 5987000, best solution: 5987000
# 2025-05-15 11:18:09,095 - routing_model [INFO] - find new solution: 6034000, best solution: 5987000
# 2025-05-15 11:18:09,100 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:09,110 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:18:09,117 - routing_model [INFO] - find new solution: 6349000, best solution: 5987000
# 2025-05-15 11:18:09,129 - routing_model [INFO] - find new solution: 6168000, best solution: 5987000
# 2025-05-15 11:18:09,149 - routing_model [INFO] - find new solution: 6215000, best solution: 5987000
# 2025-05-15 11:18:09,154 - routing_model [INFO] - find new solution: 6349000, best solution: 5987000
# 2025-05-15 11:18:09,162 - routing_model [INFO] - find new solution: 6349000, best solution: 5987000
# 2025-05-15 11:18:09,183 - routing_model [INFO] - find new solution: 6396000, best solution: 5987000
# 2025-05-15 11:18:09,189 - routing_model [INFO] - find new solution: 6530000, best solution: 5987000
# 2025-05-15 11:18:09,211 - routing_model [INFO] - find new solution: 6530000, best solution: 5987000
# 2025-05-15 11:18:09,228 - routing_model [INFO] - find new solution: 6664000, best solution: 5987000
# 2025-05-15 11:18:09,583 - routing_model [INFO] - find new solution: 6664000, best solution: 5987000
# 2025-05-15 11:18:09,598 - routing_model [INFO] - find new solution: 6664000, best solution: 5987000
# 2025-05-15 11:18:09,607 - routing_model [INFO] - find new solution: 6664000, best solution: 5987000
# 2025-05-15 11:18:09,624 - routing_model [INFO] - find new solution: 6711000, best solution: 5987000
# 2025-05-15 11:18:09,628 - routing_model [INFO] - find new solution: 6845000, best solution: 5987000
# 2025-05-15 11:18:09,636 - routing_model [INFO] - find new solution: 6845000, best solution: 5987000
# 2025-05-15 11:18:09,642 - routing_model [INFO] - find new solution: 6664000, best solution: 5987000
# 2025-05-15 11:18:10,028 - routing_model [INFO] - find new solution: 6664000, best solution: 5987000
# 2025-05-15 11:18:10,038 - routing_model [INFO] - find new solution: 6664000, best solution: 5987000
# 2025-05-15 11:18:10,065 - routing_model [INFO] - find new solution: 6483000, best solution: 5987000
# 2025-05-15 11:18:10,074 - routing_model [INFO] - find new solution: 6483000, best solution: 5987000
# 2025-05-15 11:18:10,083 - routing_model [INFO] - find new solution: 6483000, best solution: 5987000
# 2025-05-15 11:18:10,092 - routing_model [INFO] - find new solution: 6483000, best solution: 5987000
# ...
# 2025-05-15 11:22:02,263 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:22:02,287 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:02,291 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:22:02,308 - routing_model [INFO] - find new solution: 7252000, best solution: 5987000
# 2025-05-15 11:22:02,351 - routing_model [INFO] - find new solution: 7386000, best solution: 5987000
# 2025-05-15 11:22:02,365 - routing_model [INFO] - find new solution: 7520000, best solution: 5987000
# 2025-05-15 11:22:02,379 - routing_model [INFO] - find new solution: 7654000, best solution: 5987000
# 2025-05-15 11:22:02,385 - routing_model [INFO] - find new solution: 7835000, best solution: 5987000
# 2025-05-15 11:22:02,396 - routing_model [INFO] - find new solution: 8016000, best solution: 5987000
# 2025-05-15 11:22:02,408 - routing_model [INFO] - find new solution: 8197000, best solution: 5987000
# 2025-05-15 11:22:02,454 - routing_model [INFO] - find new solution: 8197000, best solution: 5987000
# 2025-05-15 11:22:02,523 - routing_model [INFO] - find new solution: 8197000, best solution: 5987000
# 2025-05-15 11:22:02,980 - routing_model [INFO] - find new solution: 8600000, best solution: 5987000
# 2025-05-15 11:22:03,051 - routing_model [INFO] - find new solution: 8016000, best solution: 5987000
# 2025-05-15 11:22:03,206 - routing_model [INFO] - find new solution: 8016000, best solution: 5987000
# 2025-05-15 11:22:03,685 - routing_model [INFO] - find new solution: 8016000, best solution: 5987000
# 2025-05-15 11:22:03,686 - routing_model [INFO] - find new solution: 8016000, best solution: 5987000
# 2025-05-15 11:22:03,687 - routing_model [INFO] - find new solution: 8016000, best solution: 5987000
# 2025-05-15 11:22:04,245 - routing_model [INFO] - find new solution: 8016000, best solution: 5987000
# 2025-05-15 11:22:04,810 - routing_model [INFO] - find new solution: 8016000, best solution: 5987000
# 2025-05-15 11:22:04,812 - routing_model [INFO] - find new solution: 8016000, best solution: 5987000
# 2025-05-15 11:22:04,925 - routing_model [INFO] - find new solution: 7835000, best solution: 5987000
# 2025-05-15 11:22:05,357 - routing_model [INFO] - find new solution: 7835000, best solution: 5987000
# 2025-05-15 11:22:05,903 - routing_model [INFO] - find new solution: 7882000, best solution: 5987000
# 2025-05-15 11:22:05,912 - routing_model [INFO] - find new solution: 8016000, best solution: 5987000
# 2025-05-15 11:22:05,978 - routing_model [INFO] - find new solution: 7835000, best solution: 5987000
# 2025-05-15 11:22:06,087 - routing_model [INFO] - find new solution: 7654000, best solution: 5987000
# 2025-05-15 11:22:06,129 - routing_model [INFO] - find new solution: 7473000, best solution: 5987000
# 2025-05-15 11:22:06,244 - routing_model [INFO] - find new solution: 7473000, best solution: 5987000
# 2025-05-15 11:22:06,584 - routing_model [INFO] - find new solution: 8510000, best solution: 5987000
# 2025-05-15 11:22:06,588 - routing_model [INFO] - find new solution: 8644000, best solution: 5987000
# 2025-05-15 11:22:06,590 - routing_model [INFO] - find new solution: 8644000, best solution: 5987000
# 2025-05-15 11:22:06,591 - routing_model [INFO] - find new solution: 7473000, best solution: 5987000
# 2025-05-15 11:22:06,605 - routing_model [INFO] - find new solution: 7473000, best solution: 5987000
# 2025-05-15 11:22:07,125 - routing_model [INFO] - find new solution: 8510000, best solution: 5987000
# 2025-05-15 11:22:07,129 - routing_model [INFO] - find new solution: 8510000, best solution: 5987000
# 2025-05-15 11:22:07,131 - routing_model [INFO] - find new solution: 7339000, best solution: 5987000
# 2025-05-15 11:22:07,183 - routing_model [INFO] - find new solution: 7339000, best solution: 5987000
# 2025-05-15 11:22:07,202 - routing_model [INFO] - find new solution: 7386000, best solution: 5987000
# 2025-05-15 11:22:07,207 - routing_model [INFO] - find new solution: 7520000, best solution: 5987000
# 2025-05-15 11:22:07,218 - routing_model [INFO] - find new solution: 7339000, best solution: 5987000
# 2025-05-15 11:22:07,695 - routing_model [INFO] - find new solution: 7339000, best solution: 5987000
# 2025-05-15 11:22:07,703 - routing_model [INFO] - find new solution: 7339000, best solution: 5987000
# 2025-05-15 11:22:07,750 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:22:07,788 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:22:07,802 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:07,819 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:07,835 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:22:07,849 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:07,851 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:07,864 - routing_model [INFO] - find new solution: 7259000, best solution: 5987000
# 2025-05-15 11:22:07,866 - routing_model [INFO] - find new solution: 7259000, best solution: 5987000
# 2025-05-15 11:22:07,894 - routing_model [INFO] - find new solution: 7259000, best solution: 5987000
# 2025-05-15 11:22:08,320 - routing_model [INFO] - find new solution: 7393000, best solution: 5987000
# 2025-05-15 11:22:08,329 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:08,334 - routing_model [INFO] - find new solution: 7259000, best solution: 5987000
# 2025-05-15 11:22:08,339 - routing_model [INFO] - find new solution: 7259000, best solution: 5987000
# 2025-05-15 11:22:08,635 - routing_model [INFO] - find new solution: 7259000, best solution: 5987000
# 2025-05-15 11:22:08,640 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:08,834 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:09,070 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:09,088 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:09,104 - routing_model [INFO] - find new solution: 7393000, best solution: 5987000
# 2025-05-15 11:22:09,170 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:09,611 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:09,616 - routing_model [INFO] - find new solution: 7259000, best solution: 5987000
# 2025-05-15 11:22:09,618 - routing_model [INFO] - find new solution: 7259000, best solution: 5987000
# 2025-05-15 11:22:10,128 - routing_model [INFO] - find new solution: 7393000, best solution: 5987000
# 2025-05-15 11:22:10,141 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:10,147 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:10,452 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:10,815 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:10,816 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:11,348 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:11,843 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:12,356 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:12,358 - routing_model [INFO] - find new solution: 7212000, best solution: 5987000
# 2025-05-15 11:22:12,381 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:12,874 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:13,062 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:13,470 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:13,471 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:13,473 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:13,992 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:14,511 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:14,513 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:15,028 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:15,343 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:15,508 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:15,510 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:15,569 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:15,856 - routing_model [INFO] - find new solution: 7527000, best solution: 5987000
# 2025-05-15 11:22:15,926 - routing_model [INFO] - find new solution: 7346000, best solution: 5987000
# 2025-05-15 11:22:16,305 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:22:16,329 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:22:16,478 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:22:16,925 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:17,436 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:17,439 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:17,948 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:18,455 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:18,966 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:19,475 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:19,554 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:20,069 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:20,071 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:20,072 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:20,127 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:22:20,319 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:22:20,738 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:22:20,739 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:22:21,297 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:22:21,298 - routing_model [INFO] - find new solution: 7165000, best solution: 5987000
# 2025-05-15 11:22:21,317 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:21,864 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:21,869 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:22,436 - routing_model [INFO] - find new solution: 7252000, best solution: 5987000
# 2025-05-15 11:22:22,462 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:23,008 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:23,013 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:23,018 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:22:23,034 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:22:23,057 - routing_model [INFO] - find new solution: 7252000, best solution: 5987000
# 2025-05-15 11:22:23,079 - routing_model [INFO] - find new solution: 7386000, best solution: 5987000
# 2025-05-15 11:22:23,091 - routing_model [INFO] - find new solution: 7339000, best solution: 5987000
# 2025-05-15 11:22:23,108 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:22:23,162 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:22:23,650 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:22:23,652 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:22:23,656 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:22:23,687 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:22:23,749 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:22:23,766 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:22:23,788 - routing_model [INFO] - find new solution: 7111000, best solution: 5987000
# 2025-05-15 11:22:23,800 - routing_model [INFO] - find new solution: 7111000, best solution: 5987000
# 2025-05-15 11:22:24,262 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:22:24,263 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:22:24,267 - routing_model [INFO] - find new solution: 7158000, best solution: 5987000
# 2025-05-15 11:22:24,292 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:22:24,294 - routing_model [INFO] - find new solution: 6977000, best solution: 5987000
# 2025-05-15 11:22:24,830 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:22:24,832 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:22:24,845 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:22:24,865 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:24,870 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:22:24,881 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:22:24,901 - routing_model [INFO] - find new solution: 7205000, best solution: 5987000
# 2025-05-15 11:22:24,920 - routing_model [INFO] - find new solution: 7024000, best solution: 5987000
# 2025-05-15 11:22:24,941 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:24,957 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:25,425 - routing_model [INFO] - find new solution: 8242000, best solution: 5987000
# 2025-05-15 11:22:25,429 - routing_model [INFO] - find new solution: 8645000, best solution: 5987000
# 2025-05-15 11:22:25,460 - routing_model [INFO] - find new solution: 8645000, best solution: 5987000
# 2025-05-15 11:22:25,480 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:25,501 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:25,514 - routing_model [INFO] - find new solution: 7118000, best solution: 5987000
# 2025-05-15 11:22:25,529 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:25,534 - routing_model [INFO] - find new solution: 7071000, best solution: 5987000
# 2025-05-15 11:22:25,879 - routing_model [INFO] - find solution
# 2025-05-15 11:22:25,879 - routing_model [INFO] - best_score: 5987.00

# %%
result.simple_routes
# Out:
# [Route(id=0, path=[1045833212, 318100290, 9806916419, 442566951], tariff=Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=990), TariffCost(min_dst_km=30.0, max_dst_km=2000.0, cost_per_km=33, fixed_cost=0)])),
#  Route(id=2, path=[340064686, 595756177], tariff=Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=990), TariffCost(min_dst_km=30.0, max_dst_km=2000.0, cost_per_km=33, fixed_cost=0)])),
#  Route(id=3, path=[2857835098, 7776310268], tariff=Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=990), TariffCost(min_dst_km=30.0, max_dst_km=2000.0, cost_per_km=33, fixed_cost=0)])),
#  Route(id=4, path=[4451788792, 11172738250], tariff=Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=990), TariffCost(min_dst_km=30.0, max_dst_km=2000.0, cost_per_km=33, fixed_cost=0)])),
#  Route(id=5, path=[5824967063, 253025355, 9806916419, 319882107], tariff=Tariff(id='ТС 0,75 тонн', mass=750, volume=1.713408, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=990), TariffCost(min_dst_km=30.0, max_dst_km=2000.0, cost_per_km=33, fixed_cost=0)])),
#  Route(id=20, path=[307998198, 43173326, 268182826, 198295539, 10090235314], tariff=Tariff(id='ТС 1,5 тонн', mass=1500, volume=8.0, cost_per_distance=[TariffCost(min_dst_km=0, max_dst_km=30.0, cost_per_km=0, fixed_cost=1037), TariffCost(min_dst_km=30.0, max_dst_km=800.0, cost_per_km=34, fixed_cost=0)]))]

# %%
result.cargo_to_route
# Out:
# {'OT-0001-00378028': 0,
#  'OT-0001-00378066': 0,
#  'OT-0001-00378161': 2,
#  'OT-0001-00378047': 3,
#  'OT-0001-00378142': 4,
#  'OT-0001-00378104': 5,
#  'OT-0001-00393324': 5,
#  'OT-0001-00378123': 20,
#  'OT-0013-00210047': 20,
#  'OT-0001-00378085': 20}

# %%
len(cargos)
# Out:
# 10

# %%
for route in result.routes:
    print('________________________________________')
    print(f"car: {route.id} mass:{route.tariff.mass} volume: {route.tariff.volume}")
    path = route.path
    g = result.cargo_graph
    max_mass = max(sum(g.nodes()[path[i]]['mass'] for i in range(j)) for j in range(len(path)))
    max_volume = max(sum(g.nodes()[path[i]]['volume'] for i in range(j)) for j in range(len(path)))
    print(f'mass: {max_mass}|{route.tariff.mass} == {max_mass / route.tariff.mass * 100:.2f}%')
    print(f'volume: {max_volume:.2f}|{route.tariff.volume:.2f} == {max_volume / route.tariff.volume * 100:.2f}%')
# Out:
# ________________________________________
# car: 0 mass:750 volume: 1.713408
# mass: 40.0|750 == 5.33%
# volume: 0.10|1.71 == 5.60%
# ________________________________________
# car: 2 mass:750 volume: 1.713408
# mass: 20.0|750 == 2.67%
# volume: 0.05|1.71 == 2.80%
# ________________________________________
# car: 3 mass:750 volume: 1.713408
# mass: 20.0|750 == 2.67%
# volume: 0.05|1.71 == 2.80%
# ________________________________________
# car: 4 mass:750 volume: 1.713408
# mass: 20.0|750 == 2.67%
# volume: 0.05|1.71 == 2.80%
# ________________________________________
# car: 5 mass:750 volume: 1.713408
# mass: 50.0|750 == 6.67%
# volume: 0.12|1.71 == 7.00%
# ________________________________________
# car: 20 mass:1500 volume: 8.0
# mass: 1040.0|1500 == 69.33%
# volume: 0.46|8.00 == 5.70%

# %%
def draw_on_map(data: PathBuildingResult,
                weight: float = 3.5,
                ) -> folium.Map:
    _g = data.cargo_graph
    u = list(_g.nodes())[0]
    u_x, u_y = _g.nodes()[u]['x'], _g.nodes()[u]['y']
    m: folium.Map = folium.Map(
        location=[u_x, u_y],
        zoom_start=11,
        tiles="cartodb positron"
    )  # Координаты города
    coords = {
    }

    for i, route in enumerate(data.routes):
        points_group = folium.FeatureGroup(name=f"points_{i}_{route.tariff.id}", show=False)
        points_group.add_to(m)
        path = route.path
        for i in range(len(path)):
            u = path[i]
            du = _g.nodes()[u]
            x, y = du['x'] + random.random() / 1000, du['y'] + random.random() / 1000
            coords[i] = (x, y)
            time = sum(data.cargo_graph.edges()[path[j], path[j + 1]]['time'] + data.cargo_graph.nodes()[path[j]]['service_time'] for j in range(i))
            
            test = f"""
            
            номер груза:       {path[i][0]}<br>
            номер ноды в графе:       {path[i][1]}<br>
            порядок посещения:      {i}<br>
            время:                  {time:.2f}<br>
            время обслуживание:     {data.cargo_graph.nodes()[path[i]]['service_time']:.2f}<br>
            """
            popup = folium.Popup(test, max_width=300, min_width=300)
            color = _g.nodes()[path[i]]['color'] if 'color' in _g.nodes()[path[i]] else 'red' if _g.nodes()[path[i]][
                                                                                                     'mass'] < 0 else 'blue'
            folium.CircleMarker(
                location=(x, y),
                radius=8,
                fill=True,
                fill_color=color,
                color=color,
                fill_opacity=0.7,
                popup=popup
            ).add_to(points_group)

        for i in range(len(path) - 1):
            u_x, u_y = coords[i]
            v_x, v_y = coords[i + 1]
            mass_by_edge = sum(_g.nodes()[path[j]]['mass'] for j in range(i + 1))
            volume_by_edge = sum(_g.nodes()[path[j]]['volume'] for j in range(i + 1))

            test = f"""
                масса на плече: {mass_by_edge:.2f}<br>
                объем на плече: {volume_by_edge:.2f}<br>
                длина плеча:    {_g.edges()[path[i], path[i + 1]]['length'] / 1000:.2f} <br>
                время:          {_g.edges()[path[i], path[i + 1]]['time']:.2f}
            """
            popup = folium.Popup(test, max_width=300, min_width=300)
            folium.PolyLine(
                [(u_x, u_y), (v_x, v_y)],
                weight=weight,
                color='blue',
                popup=popup
            ).add_to(points_group)
    folium.LayerControl().add_to(m)
    return m

# %%
m = draw_on_map(result)

# %%
m.show_in_browser()
# Out:
# Your map should have been opened in your browser automatically.
# Press ctrl+c to return.

# %%
# m.save('map.html')
